# %%
from openai import OpenAI
import os

# 初始化 OpenAI 客户端
# 使用阿里云 DashScope 的兼容模式 API
client = OpenAI(api_key="sk-882e296067b744289acf27e6e20f3ec0",
                base_url="https://dashscope.aliyuncs.com/compatible-mode/v1")

# 初始化变量用于存储模型的推理内容和最终回答内容
reasoning_content = ""  # 存储模型的推理过程
content = ""  # 存储模型的最终回答

# 标记是否已经开始输出最终回答
is_answering = False

# 创建聊天完成请求
# 使用 qwq-32b 模型，并启用流式输出
completion = client.chat.completions.create(
    model="qwq-32b",
    messages=[
        {"role": "user", "content": "9.9和9.11 哪个更大？"}
    ],
    stream=True,
    # 取消下面的注释可以在最后一个数据块中返回 token 使用情况
    # stream_options={
    #     "include_usage": True
    # }
)

# 打印推理内容的分隔标题
print("\n" + "=" * 20 + "reasoning content" + "=" * 20 + "\n")

# 处理流式响应的每个数据块
for chunk in completion:
    # 如果 chunk.choices 为空，打印使用情况统计
    if not chunk.choices:
        print("\nUsage:")
        print(chunk.usage)
    else:
        # 获取当前数据块中的增量内容
        delta = chunk.choices[0].delta
        
        # 处理推理内容部分
        # QwQ 模型的特殊功能：可以输出推理过程
        if hasattr(delta, 'reasoning_content') and delta.reasoning_content is not None:
            print(delta.reasoning_content, end='', flush=True)  # 实时打印推理内容
            reasoning_content += delta.reasoning_content  # 累积推理内容
        else:
            # 处理最终回答内容部分
            # 当首次收到回答内容时，打印分隔标题
            if delta.content != "" and is_answering is False:
                print("\n" + "=" * 20 + "content" + "=" * 20 + "\n")
                is_answering = True
                
            # 打印回答内容
            print(delta.content, end='', flush=True)  # 实时打印回答内容
            content += delta.content  # 累积回答内容
# Out:
# ====================reasoning content====================
#
# 嗯，用户问的是9.9和9.11哪个更大。首先我要确定这两个数字的大小比较。看起来像是小数的比较，不过有时候可能会有不同的解释，比如版本号或者日期之类的，不过这里应该只是普通的数字比较吧。
#
# 首先，我需要回忆一下小数的比较方法。比较两个小数的时候，先比整数部分，整数部分大的那个数就大。如果整数部分相同，再逐位比较小数部分。比如，像9.9和9.11，它们的整数部分都是9，所以接下来要看小数部分。
#
# 接下来是小数部分的比较。第一个数字是0.9，第二个是0.11。这时候可能需要把它们的小数部分对齐到相同的小数位数，或者直接比较每一位。比如0.9可以写成0.90，而0.11就是两位小数。这样比较的话，第一位小数位是9和1，显然9比1大，所以0.90比0.11大，因此整个数9.9比9.11大。
#
# 不过，也有可能用户是想问的是像版本号的情况，比如9.9和9.11在版本号里，这时候比较方式可能不同。比如在版本号中，数字后面的数字可能会按数字分隔比较，例如9.11的版本号中的11其实是两位数字，所以可能比9.9的版本号更高。比如9.9相当于9.09，而9.11则是9.11，这时候9.11会比9.09大。这时候结果就会相反。
#
# 但通常如果没有特别说明是版本号或者其他特殊含义，应该按照普通的数值比较来处理。所以这个时候9.9是9.90，而9.11是9.11，显然9.90的小数部分第一位是9，而9.11的第一位是1，所以9.9更大。
#
# 不过可能有人会误解，比如认为11比9大，所以9.11更大，这时候需要澄清比较的方法。例如，在小数比较中，每一位都要逐位比较，而不是看整个小数部分的数值。比如0.9和0.11，第一位小数是9和1，9比1大，所以0.9更大，后面的小数位数不影响，因为前面已经分出胜负了。
#
# 或者，用户可能输入的时候有笔误，比如是不是9.11其实是9.1，但看起来应该是9.11。或者可能用户是想问9.9和9.11哪个更大，可能在某些特定情况下有不同的解释，但通常数值上9.9更大。
#
# 不过为了确保正确，我需要再仔细检查一遍。例如，把两个数转换成分数可能会更清楚。9.9等于9又9/10，即99/10，而9.11是9又11/100，即911/100。比较这两个分数的话，可以通分，99/10等于990/100，而911/100显然小于990/100，所以9.9更大。
#
# 或者用小数点后两位来比较，9.90和9.11，显然第一位小数9比1大，所以前者更大。
#
# 不过也有可能用户混淆了小数点的位置，比如9.11是否应该是9.1，或者是否有其他写法，但按照通常的写法，9.11是两位小数，所以应该是正确的。
#
# 总结一下，按照常规的数值比较，9.9大于9.11，因为小数点后的第一位9比1大。而如果是版本号的话，可能要看具体情况，但用户没有提到版本号，所以应该以数值比较为准。
# ====================content====================
#
# 在数值比较中，**9.9 比 9.11 大**。
#
# ### 具体分析：
# 1. **整数部分比较**：
#    两个数的整数部分都是 **9**，因此需要比较小数部分。
#
# 2. **小数部分逐位比较**：
#    - **9.9** 的小数部分是 **0.9**（等价于 **0.90**）。
#    - **9.11** 的小数部分是 **0.11**。
#    - **第一位小数位**：
#      - 0.9 的第一位是 **9**，
#      - 0.11 的第一位是 **1**。
#      显然，**9 > 1**，因此 **0.9 > 0.11**。
#
# 3. **结论**：
#    因此，**9.9 > 9.11**。
#
# ---
#
# ### 可能的误区：
# - **版本号比较**：
#   如果是版本号（如 `9.9` 和 `9.11`），通常会将小数部分视为数字分隔比较（例如 `9.11` 的 `11` 比 `9.9` 的 `9` 大）。但题目未明确说明是版本号，因此默认按数值比较。
#
# - **小数位数差异**：
#   将 **9.9** 写作 **9.90** 后，与 **9.11** 对齐比较，结果一致。
#
# ---
#
# ### 数学验证：
# - **分数形式**：
#   - 9.9 = \( \frac{99}{10} = \frac{990}{100} \)，
#   - 9.11 = \( \frac{911}{100} \)。
#   显然，\( \frac{990}{100} > \frac{911}{100} \)。
#
# ---
#
# **最终答案**：
# 9.9 比 9.11 大。
